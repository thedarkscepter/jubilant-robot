# %% [markdown]
# <a href="https://colab.research.google.com/github/thedarkscepter/jubilant-robot/blob/main/Movie_clazzz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-aba465f2-f811-4613-86c7-d08df25925d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aba465f2-f811-4613-86c7-d08df25925d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
#  56% 5.00M/8.89M [00:01<00:01, 3.48MB/s]
# 100% 8.89M/8.89M [00:01<00:00, 5.94MB/s]

# %%
# !unzip tmdb-movie-metadata.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
#   inflating: tmdb_5000_credits.csv
#   inflating: tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('tmdb_5000_credits.csv')
df2 = pd.read_csv('tmdb_5000_movies.csv')
df1.head(10000
         )
# Out:
#       movie_id  ...                                               crew
# 0        19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1          285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2       206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3        49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4        49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...        ...  ...                                                ...
# 4798      9367  ...  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799     72766  ...  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800    231617  ...  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801    126186  ...  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802     25975  ...  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4803 rows x 4 columns]

# %%
df2.head(10000)
# Out:
#          budget  ... vote_count
# 0     237000000  ...      11800
# 1     300000000  ...       4500
# 2     245000000  ...       4466
# 3     250000000  ...       9106
# 4     260000000  ...       2124
# ...         ...  ...        ...
# 4798     220000  ...        238
# 4799       9000  ...          5
# 4800          0  ...          6
# 4801          0  ...          7
# 4802          0  ...         16
#
# [4803 rows x 20 columns]

# %%
df1.columns = ['id', 'title', 'cast', 'crew']
df2 = df2.merge(df1, on = 'id')
df2.head(5)
# Out:
#       budget  ...                                             crew_y
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 26 columns]
